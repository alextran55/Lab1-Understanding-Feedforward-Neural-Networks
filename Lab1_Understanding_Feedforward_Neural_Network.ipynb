# %% [markdown]
# <a href="https://colab.research.google.com/github/alextran55/Lab1-Understanding-Feedforward-Neural-Networks/blob/main/Lab1_Understanding_Feedforward_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b>Understanding Feedforward Neural Network</b>

# %% [markdown]
# In this lab, you are required to build 3 Feedforward Neural Networks to simulate function
# <br> $y = xsin( \frac {x^2} {300})$
# <br> in range x: +-100
# <br> You need to have a different structure for each model you build.

# %% [markdown]
# ##Requirements

# %% [markdown]
# 1 You are required to finish each part below following instructions.
# <br>2 You may work on native py files, but your work needs to include same documentation. You may use pytorch or tensorflow keras.
# <br>3 You may work in a group of 2.
#
# <br><b>For submission, submit a link to your github repo</b>
# <br>All student in the group must submit.

# %% [markdown]
# #### Part 1 data preparation
#
# In the cell below, generate training data for your model.
# <br> Generate a decent amount of training data in the interval of x.
# <br>
# <br> Since we are only approximating a function, data can be generated by plug in x value and get corresponding y value.
# <br>You may use the way to generate data as in file Introduction_to_Artificial_Neural_Network.ipynb ([np.linspace](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html))
# <br>
# <br>All data need to be separated by the same distance.
# <br>Ex:if you select an intervel from -100 to +100, and a total of 10001 data points, each x coordinate should be separated by 0.02

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# Generate the data
xc = np.linspace(-100, 100, 10001)
yc = xc*np.sin((xc**2)/300)

plt.plot(xc, yc)
plt.show()

# %% [markdown]
# #### Part 2 build models
#
# In the cells below, build your models and train it with data from part1.
# <br>
# <br> You may use the model built in file Introduction_to_Artificial_Neural_Network.ipynb and change number of layers, number of neurons in each layer, activation function, loss function (loss), batch size, and/or epochs of the model. Or you can build your own model from scratch.
# <br>
# <br>Observe the change in training process (training time, accuracy changing rate) and final results when you change the parameters.
# <br>
# <br>You need to split your training data to two parts. With 40% used in training, and 60% used in test. You may do this with sklearn's [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) or keras' [validation_split](https://keras.io/api/models/model_training_apis/#fit-method) parameter in fit method together with train_test_split().

# %%
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Activation, Flatten
from sklearn.model_selection import train_test_split

# Splitting data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(xc, yc, test_size=0.6, random_state=42)

# model 1
model = Sequential()
model.add(Input(shape=(1,)))
model.add(Dense(150,activation = "relu"))
model.add(Dense(150,activation = "LeakyReLU"))
model.add(Dense(150,activation = "ThresholdedReLU"))
model.add(Dense(150,activation = "PReLU"))
model.add(Dense(150,activation = "ELU"))
model.add(Dense(150,activation = "relu"))
model.add(Dense(1))

model.compile(loss = 'MAE', optimizer = 'Adam', metrics=['mae'])
model.fit(X_train, Y_train, batch_size=128, epochs=50)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 2s 6ms/step - loss: 31.7097 - mae: 31.7097
# Epoch 2/50
# 32/32 [==============================] - 0s 7ms/step - loss: 31.4101 - mae: 31.4101
# Epoch 3/50
# 32/32 [==============================] - 0s 6ms/step - loss: 31.1951 - mae: 31.1951
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 31.0661 - mae: 31.0661
# Epoch 5/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.9779 - mae: 30.9779
# Epoch 6/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.7942 - mae: 30.7942
# Epoch 7/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.9205 - mae: 30.9205
# Epoch 8/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.7008 - mae: 30.7008
# Epoch 9/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.6291 - mae: 30.6291
# Epoch 10/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.5238 - mae: 30.5238
# Epoch 11/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.4532 - mae: 30.4532
# Epoch 12/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.4829 - mae: 30.4829
# Epoch 13/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.2783 - mae: 30.2783
# Epoch 14/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.0685 - mae: 30.0685
# Epoch 15/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.0915 - mae: 30.0915
# Epoch 16/50
# 32/32 [==============================] - 0s 6ms/step - loss: 30.1162 - mae: 30.1162
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.7498 - mae: 29.7498
# Epoch 18/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.6239 - mae: 29.6239
# Epoch 19/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.5993 - mae: 29.5993
# Epoch 20/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.6345 - mae: 29.6345
# Epoch 21/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.3830 - mae: 29.3830
# Epoch 22/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.2250 - mae: 29.2250
# Epoch 23/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.1608 - mae: 29.1608
# Epoch 24/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.0411 - mae: 29.0411
# Epoch 25/50
# 32/32 [==============================] - 0s 6ms/step - loss: 29.0205 - mae: 29.0205
# Epoch 26/50
# 32/32 [==============================] - 0s 7ms/step - loss: 28.8343 - mae: 28.8343
# Epoch 27/50
# 32/32 [==============================] - 0s 15ms/step - loss: 29.0543 - mae: 29.0543
# Epoch 28/50
# 32/32 [==============================] - 1s 16ms/step - loss: 28.8939 - mae: 28.8939
# Epoch 29/50
# 32/32 [==============================] - 0s 13ms/step - loss: 28.7302 - mae: 28.7302
# Epoch 30/50
# 32/32 [==============================] - 0s 12ms/step - loss: 28.6074 - mae: 28.6074
# Epoch 31/50
# 32/32 [==============================] - 1s 16ms/step - loss: 28.8076 - mae: 28.8076
# Epoch 32/50
# 32/32 [==============================] - 1s 21ms/step - loss: 28.7068 - mae: 28.7068
# Epoch 33/50
# 32/32 [==============================] - 1s 15ms/step - loss: 28.8030 - mae: 28.8030
# Epoch 34/50
# 32/32 [==============================] - 0s 13ms/step - loss: 28.8704 - mae: 28.8704
# Epoch 35/50
# 32/32 [==============================] - 0s 13ms/step - loss: 28.3398 - mae: 28.3398
# Epoch 36/50
# 32/32 [==============================] - 0s 7ms/step - loss: 28.3084 - mae: 28.3084
# Epoch 37/50
# 32/32 [==============================] - 0s 6ms/step - loss: 28.1052 - mae: 28.1052
# Epoch 38/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.9801 - mae: 27.9801
# Epoch 39/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.6852 - mae: 27.6852
# Epoch 40/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.6765 - mae: 27.6765
# Epoch 41/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.4806 - mae: 27.4806
# Epoch 42/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.8932 - mae: 27.8932
# Epoch 43/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.5859 - mae: 27.5859
# Epoch 44/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.0117 - mae: 27.0117
# Epoch 45/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.5212 - mae: 27.5212
# Epoch 46/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.4920 - mae: 27.4920
# Epoch 47/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.4051 - mae: 27.4051
# Epoch 48/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.4782 - mae: 27.4782
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.5119 - mae: 26.5119
# Epoch 50/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.5956 - mae: 26.5956

# %%
# model 2
model2 = Sequential()
model2.add(Input(shape=(1,)))
model2.add(Dense(100, activation='relu'))
model2.add(Dense(100, activation='relu'))
model2.add(Dense(100, activation='tanh'))
model2.add(Dense(1))

model2.compile(loss='mse', optimizer='Adam', metrics=['mae'])
model2.fit(X_train, Y_train, batch_size=64, epochs=40)
# Out:
# Epoch 1/40
# 63/63 [==============================] - 1s 2ms/step - loss: 1672.1730 - mae: 31.4702
# Epoch 2/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1668.3826 - mae: 31.3924
# Epoch 3/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1667.1796 - mae: 31.3622
# Epoch 4/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1674.7798 - mae: 31.3454
# Epoch 5/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1673.1818 - mae: 31.3379
# Epoch 6/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1668.5055 - mae: 31.3077
# Epoch 7/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1667.0404 - mae: 31.2830
# Epoch 8/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1666.4619 - mae: 31.2814
# Epoch 9/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1665.8563 - mae: 31.2178
# Epoch 10/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1665.6714 - mae: 31.1295
# Epoch 11/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1664.5355 - mae: 31.1128
# Epoch 12/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1665.7842 - mae: 31.0911
# Epoch 13/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1661.7937 - mae: 31.0036
# Epoch 14/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1659.9198 - mae: 30.9403
# Epoch 15/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1657.2228 - mae: 30.8473
# Epoch 16/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1655.1483 - mae: 30.7572
# Epoch 17/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1654.0891 - mae: 30.6721
# Epoch 18/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1650.6238 - mae: 30.5496
# Epoch 19/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1648.7281 - mae: 30.4635
# Epoch 20/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1646.1501 - mae: 30.3406
# Epoch 21/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1643.0430 - mae: 30.2185
# Epoch 22/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1639.7593 - mae: 30.0744
# Epoch 23/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1637.8522 - mae: 29.9701
# Epoch 24/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1635.4829 - mae: 29.8502
# Epoch 25/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1633.4296 - mae: 29.7767
# Epoch 26/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1632.1332 - mae: 29.6850
# Epoch 27/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1630.8466 - mae: 29.6007
# Epoch 28/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1630.9899 - mae: 29.6203
# Epoch 29/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1629.3276 - mae: 29.5150
# Epoch 30/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1628.2382 - mae: 29.4131
# Epoch 31/40
# 63/63 [==============================] - 0s 4ms/step - loss: 1627.6487 - mae: 29.3679
# Epoch 32/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1627.1594 - mae: 29.3251
# Epoch 33/40
# 63/63 [==============================] - 0s 3ms/step - loss: 1626.8302 - mae: 29.2965
# Epoch 34/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1626.4852 - mae: 29.2526
# Epoch 35/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1625.9559 - mae: 29.1936
# Epoch 36/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1626.0985 - mae: 29.1920
# Epoch 37/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1626.3300 - mae: 29.2166
# Epoch 38/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1625.5129 - mae: 29.1353
# Epoch 39/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1625.3146 - mae: 29.0771
# Epoch 40/40
# 63/63 [==============================] - 0s 2ms/step - loss: 1625.3193 - mae: 29.0882

# %%
# model 3
model3 = Sequential()
model3.add(Input(shape=(1,)))
model3.add(Dense(200, activation='relu'))
model3.add(Dense(150,activation = "relu"))
model3.add(Dense(100,activation = "relu"))
model3.add(Dense(50, activation='sigmoid'))
model3.add(Dense(1))

model3.compile(loss='mse', optimizer='Adam', metrics=['mae'])
model3.fit(X_train, Y_train, batch_size=64, epochs=30)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 1s 3ms/step - loss: 1672.1921 - mae: 31.6623
# Epoch 2/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1669.3064 - mae: 31.5377
# Epoch 3/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.9211 - mae: 31.5045
# Epoch 4/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.6001 - mae: 31.4763
# Epoch 5/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1670.0386 - mae: 31.4079
# Epoch 6/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.5791 - mae: 31.3670
# Epoch 7/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.4214 - mae: 31.3405
# Epoch 8/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.3408 - mae: 31.3338
# Epoch 9/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.7479 - mae: 31.3660
# Epoch 10/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1667.9979 - mae: 31.3240
# Epoch 11/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1668.2632 - mae: 31.2755
# Epoch 12/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1664.8610 - mae: 31.1643
# Epoch 13/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1662.2478 - mae: 31.0652
# Epoch 14/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1660.7035 - mae: 31.0083
# Epoch 15/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1658.1959 - mae: 30.9082
# Epoch 16/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1656.8955 - mae: 30.8440
# Epoch 17/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1655.9331 - mae: 30.8070
# Epoch 18/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1654.7545 - mae: 30.7443
# Epoch 19/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1654.1617 - mae: 30.7121
# Epoch 20/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1653.7806 - mae: 30.7046
# Epoch 21/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1652.6208 - mae: 30.6397
# Epoch 22/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1652.0104 - mae: 30.5974
# Epoch 23/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1651.5555 - mae: 30.5731
# Epoch 24/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1650.8997 - mae: 30.5347
# Epoch 25/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1650.4918 - mae: 30.5296
# Epoch 26/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1651.3757 - mae: 30.6191
# Epoch 27/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1650.4808 - mae: 30.5427
# Epoch 28/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1649.3502 - mae: 30.4465
# Epoch 29/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1649.0897 - mae: 30.4201
# Epoch 30/30
# 63/63 [==============================] - 0s 3ms/step - loss: 1648.7161 - mae: 30.3900

# %% [markdown]
# #### Part 3 model evaluation
#
# In the cells below, eval your model with training data, test data ( with [model.evaluate()](https://keras.io/api/models/model_training_apis/#evaluate-method) ), and plot your predict result on the same plot with the plot of goal function.

# %%
y_pred1 = model.predict(xc)
y_pred2 = model2.predict(xc)
y_pred3 = model3.predict(xc)

plt.plot(xc, yc, label='True Function', color='black')
plt.plot(xc, y_pred1, label='Model 1 Prediction', linestyle='dashed', alpha=0.7)
plt.plot(xc, y_pred2, label='Model 2 Prediction', linestyle='dotted', alpha=0.7)
plt.plot(xc, y_pred3, label='Model 3 Prediction', linestyle='dashdot', alpha=0.7)
plt.title('Model Predictions vs Goal Function')
plt.legend()
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# #### Part 4 get model output and feedforward by yourself
#
# Recall how a Feedforward Neural Network gets its output. Now choose your model with highest accuracy, and call [get_weights()](https://keras.io/api/layers/base_layer/#get_weights-method) to get its weights and bias.
# <br>
# <br> Hint: bias and weights have different dimensions in most cases. Try to guess which index represent bias before you look it up on the internet.
#
# <br> Afterwards, choose 5 data from your training dataset, do all the necessary calculations (with program of course), and get the output of your model. Compare it to the [model.predict()](https://keras.io/api/models/model_training_apis/#predict-method) result.
# <br> They should be identical for the first several digitals, if not for all digits.
# <br>
# <br> If you do not know what are the necessary calculations, they are the steps mentioned in file Introduction_to_Artificial_Neural_Network.ipynb
# <br> Matrix transpose can be done easily with [pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transpose.html) or [numpy](https://numpy.org/doc/stable/reference/generated/numpy.matrix.transpose.html). Activation functions can be applied with [keras' activation functions](https://keras.io/api/layers/activations/#available-activations).

# %%
model1_weights_and_biases = model.get_weights()
